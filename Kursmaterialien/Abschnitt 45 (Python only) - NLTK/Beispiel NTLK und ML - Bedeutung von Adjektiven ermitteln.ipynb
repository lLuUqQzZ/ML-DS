# %% [markdown]
# Datenquelle: https://www.kaggle.com/snap/amazon-fine-food-reviews
#
# Davon betrachten wir nur die ersten 10.000 Zeilen.

# %%
import pandas as pd

df = pd.read_csv("./Reviews_10000.csv.bz2")
df.head()
# Out:
#    Id   ProductId  HelpfulnessNumerator  HelpfulnessDenominator  Score  \
# 0   1  B001E4KFG0                     1                       1      5
# 1   2  B00813GRG4                     0                       0      1
# 2   3  B000LQOCH0                     1                       1      4
# 3   4  B000UA0QIQ                     3                       3      2
# 4   5  B006K2ZZ7K                     0                       0      5
#
#          Time                Summary  \
# 0  1303862400  Good Quality Dog Food
# 1  1346976000      Not as Advertised
# 2  1219017600  "Delight" says it all
# 3  1307923200         Cough Medicine
# 4  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %%
texts = df["Text"]

# %%
import nltk

texts_transformed = []
for review in texts: 
    sentences = nltk.sent_tokenize(review)
    adjectives = []
    
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        words_tagged = nltk.pos_tag(words)
        
        for word_tagged in words_tagged:
            if word_tagged[1] == "JJ":
                adjectives.append(word_tagged[0])
                
    texts_transformed.append(" ".join(adjectives))

# %%
texts_transformed
# Out:
# ['several good processed finicky',
#  'small unsalted sure',
#  'few light pillowy tiny powdered tiny chewy flavorful yummy familiar',
#  'secret good cherry medicinal',
#  'great wide quick',
#  'wild enjoyable many only much licorice-flavored particular delightful',
#  'great soft expensive beach-themed',
#  'good soft satisfying',
#  '',
#  'healthy Good good small required',
#  'unique hot bummed. ecstatic it. hot sauce..I hot other personal incredible',
#  'other protein-rich skinny',
#  'new different new full similar new',
#  'good fresh delicious',
#  'guilty',
#  '',
#  'good sweet fresh',
#  'satisfied',
#  'favorite br dry Record-Breaking',
#  'reasonable unable',
#  'many fresh tasty arrive timely',
#  'overseas < generous 16-ounce',
#  'superb',
#  'weight',
#  'miss YUM < faithful able',
#  'advertised.',
#  'red',
#  'glad hard such unique',
#  'diabetic unnecessary sweet sugar-free great much free impressed i w i sugary',
#  'unique hot bummed. ecstatic it. hot sauce..I hot other personal incredible',
#  'huge little other non-coffee < little super easy good good',
#  'great great br',
#  'great instant good oatmeal stovetop good instant organic all-natural good boiling convenient issue. actual high fructose Real harmful other tasty guar instant thick',
#  'good oatmeal high cold brown regular good',
#  'Instant soggy excellent good same regular excellent instant close non-instant 10-Count',
#  '10-Count steel-cut instant hardy sweet great post-bariatric palatable digestible',
#  'celiac instant',
#  'half low-fat add expensive little',
#  '',
#  'happy happy 10-Count',
#  'great < up. brown terrific same ole great. small good sure healthy quick excellent cheap',
#  'raw good sure instant available different different other well-known top little twenty-seven much bad bad ten-count good whole single',
#  'able great great healthy',
#  'good sugary good hot excellent',
#  'often. convenient. oatmeal good',
#  'wholesome mushy much',
#  'Good soupy thick',
#  'good',
#  'fine brown quick easy',
#  'same big healthy carbs',
#  'good soft',
#  'free mary hot nice',
#  'last hot advertised cold nose ordinary ordinary nose < important insulted',
#  'south much',
#  'stove-top popcorn well-suited first second distinct dark great strong persistent smooth',
#  'large wonderful roasted delicious smooth bitter numerous roasted',
#  'awesome indicated expensive local',
#  'chocolate',
#  'nice perfect',
#  'fresh many',
#  'good < 3-4',
#  'expensive other good favorite',
#  'stale',
#  'endurolyte several camelbak tasty effective several mile great endurolyte great endurance Second Third great nice refreshing bottled nice flavored full hammer',
#  'long slight other whole',
#  'latter fine easy',
#  'low diet little many high plain little loaded low-carb particular leg these.',
#  'various familiar appealing terrible bad bad',
#  'impulsive wrong good little ridiculous',
#  'sooooo deliscious bad i',
#  'Albanese good tasty high little local twin concerned deep',
#  'hard much little other sour strong good gummy little flavored awesome delicious',
#  'fresh intact good soft good great impressed',
#  'undigestible short unsuspecting many extreme intestinal massive hard sugar-free sugar-free first short terrible painful abdominal unpleasant low delicious sugar-free local amazing new sugarfree good little asterisk next maltitol tiny little little same much bad',
#  'okay',
#  'whole artifial returnable',
#  'perfect trail solid melted few good',
#  'good different similar other warm cold last',
#  'great cold',
#  'good south i sweet',
#  'delicious similar little',
#  'giant',
#  'own sweet flavored full bad manufactured good other cold own low-fat non-instant regular non-instant little regular instant good cold hot heavy rich expensive own cocoa bean small own flavored fake small little top storebought fun own essential next good online low-fat great sure other molecular able sure main own great',
#  'itchy limited Natural',
#  'severe different glad other',
#  'great hot problems. right free',
#  'environmental allergic environmental happy',
#  'limited free',
#  'Natural awful last last allergic dry other',
#  'Great real good regular perfect',
#  'standard different due natural',
#  'great dog only',
#  'great old puppy soft sick good',
#  'golden picky various natural natural multiple dry wet dry little wet golden same meal little fish < natural',
#  'same same',
#  'pleased other past recommend free possible allergic helpful different kibble sized',
#  '1-1/2 old energetic standard natural happy full normal 1-1/2 natural much last normal free 2-day sold',
#  'other cheap crazy',
#  'English previous new second limited sensitive commercial',
#  'terrible super',
#  'only heavy',
#  'helpful full',
#  'perfect crazy sour/tart great',
#  'scrumptuous expensive',
#  'nice',
#  'easy great',
#  'excellent',
#  'Amish first local Amish fantastic',
#  'exact great much',
#  'diet possible diet tasty non-fat low asparagus several pickled good excellent big garlic good asparagus good',
#  'specific',
#  'long available glad other Wonderful',
#  'several many much healthy many alternative green good Green few other only quality cold green beautiful golden bright fresh tiny expense fantastic practical < different contributive possible sure green free other hot',
#  'clean bright fresh < great',
#  'green hard internet big many green',
#  '',
#  'Italian everyday Italian great',
#  'several mid-day simple delicious good recent great great',
#  'little local small diet overweight soft posh many good other feline lousy healthy vegetarian tuned. good little much big female old couple healthy tiny happy chicken sardine',
#  'old real other sure other good great past active sooo soft',
#  'excellent holistic kibble last important old Holistic',
#  'old much satisfied added',
#  'old male urinary dry wet dry other expensive',
#  'feline addicted dry wish dry old old good several local holistic only other usual finicky good palatable finicky',
#  'holistic few other sardine soft clean clear rude odorous definite obvious Holistic',
#  'allergic few available active soft shiny fat',
#  'dry hair great fit fast top',
#  'long spice bad expensive',
#  'little hot good',
#  'sure healthy',
#  'easy decent amazing',
#  'good',
#  'hot hot',
#  'local GREAT real favorite',
#  'different',
#  'other prime bad',
#  'unbelievable fibrous real perfect worth',
#  'Australian other',
#  'other Stupid soooo',
#  'available other',
#  'sweet bite entire only open',
#  'other free good black cherry good strawberry delicate',
#  'tasty reasonable subscribe several other',
#  'messy sure soft easy sticky gross nice great',
#  'many certain enough eating old same',
#  'comparable nice smooth small sweet sweet mild nice little',
#  'delicious several little NEW CAREFUL',
#  'long other',
#  'favorite',
#  'regular hot outstanding great',
#  'fabulous enough super',
#  'chicken fish easy excellent',
#  'pretty good',
#  'sure favorite good',
#  'such yummy healthy glad many good good wonderful',
#  'green wonderful harvest regular',
#  'last regular',
#  '',
#  'tiny > < tomato delicious many < short like. good many',
#  'typical surprised other',
#  'great',
#  'Star-Kist pleasant much other',
#  'familiar good great low low fat',
#  "Excellent up'. little",
#  'tasteless much special',
#  'little decadent dark syrupy sour little unique metallic fesenjan next',
#  'brilliant mixed swirled sliced wonderful',
#  'long old clear dried returnable different fifty',
#  'same same good Yucky',
#  'fine alot great open',
#  'small small',
#  'much instant French live hidden <',
#  'delicious other',
#  'fresh creamy cinnamon available fair cinnamon perfect large white top large thick solid sponge moist filling sticky sweet sticky sweet perfect',
#  'lemon strong alive strong good same lemon bad good',
#  'due high fresh <',
#  'lemon kitchen powerful',
#  'good same lemon handy Such fresh',
#  'good good odd Sure wish frozen',
#  'ready other tingle short droopy',
#  'great bad low',
#  'great great natural',
#  'natural busy good second asleep stay first ready sleepy-drug huge marginal broken small-bubbled bubble extra Big awesome',
#  'fantastic brown bean other classic other gluten-free nice same regular added high 2-3 glycemic lower. only',
#  'great tasty Good',
#  'flour local',
#  'secret European fresh pie strawberry amazing healthy uncooked fresh made-up arranged rich gorgeous clear nice thin shallow other pate French straight-sided pre-baking commercial pate substantial fresh great must-have vegan locust vegan tofu nut',
#  'full hot hot strong bad tolerablel',
#  'much organic other healthy good few worth expensive similar few',
#  'other slight overwhelming',
#  'great organic good',
#  "other great different instant organic 'Africafe instant",
#  'great br resealable hard fantastic crazy',
#  'little tasty refreshing. terrible small sugar free bacteria great tasty lunch. good',
#  'regular costly',
#  'little free great deal.There go.Fifty right cary sugar.The resonable.Also great ones.Youll glad',
#  '/ enough br fresh regular real <',
#  'careful many same',
#  'strong great',
#  'huge effective 7-11',
#  'small little exotic costly tiny',
#  'empty little small powerful',
#  'great',
#  'own real able good nice tasty free good full easy',
#  'tiny great quick small great full couple',
#  'small square blue delicious regular-size recommended',
#  'Fresh few',
#  'wintergreen sugar free red such common delicious right',
#  'regular breath pleasant-tasting little cute strong dragon-breath small short free',
#  'picky them. certain senior few litter small kibble br consistent appropriate < super soft lush- new loyal',
#  'overweight grouchy previous old ten old happy previous',
#  'eleven old fifteen other arthritic skinny. such senior low entire other active effective.',
#  'much good kibble national natural',
#  'same new upset loud normal much other < sensitve picky horrible',
#  'few first olive several favorite',
#  'un-like other subtle great favorite',
#  'approximate',
#  'hot edible good sized sour due different super hot much. easy vegetable chicken affected extra olive vegetable oil. next',
#  'few retail little online great great strong full-bodied black enough current favorite jaded',
#  'strong full irish early other full bitter palatable other iced hot excellent full',
#  'pleasant local right herbal Imperial black affordable expensive black white',
#  'complex full good clean complete long lasting finish busy interested lose 2-3',
#  'Russian due delicious hot iced',
#  'excellent great',
#  'real herbal',
#  'tasty super easy raw slimy snow little red wonderful',
#  'other much natural tasty little',
#  'little Bloody',
#  '',
#  'hard smooth good',
#  'hooked satisfying extra',
#  'several subtle natural Organic Proprietary Other Natual different',
#  'wonderful red wonderful',
#  'Terrible Artificial plain fresh grated',
#  'huge subtle favorite good flavored long',
#  'white flat regular bad cheese full long Wrong small bad biodegradable eco-friendly small all. other little <',
#  'ultimate puppy great small High digestible high various multiple satisfied recent good',
#  'lhasa/bichon lhasa/poodle expensive pleased small such dogs. first great wrong soft responsible due high necessary small useful long Much much whole',
#  'delicate green smooth light subtle floral bitter superb consistent happy available few few current much < great happy',
#  'great little',
#  'br happy available surprised negative superb consistent current good <',
#  'good local',
#  'black past favorite black favorite next',
#  'other same Russian Italian',
#  'excellent eith hot iced',
#  'past large metropolitan many Middle-Eastern loose 5-7 unremarkable robust enough beautiful reddish good own decent characteristic weak flat tasteless same such much',
#  'many many other assemble nice easy great fast',
#  'extra great second',
#  'good fast happy little few good few anywhere def',
#  'daily clean free',
#  'impressive small great economical fresh due unbaked excited fast easy other',
#  'tasty same dry dry frozen',
#  'durable',
#  'chemical sensitive sugar-free sweet early full many toxic clean nasty',
#  '',
#  'high other un-healthy shot other top much good full other caffeine organic safe. NOT sensitive great easy pleasant 5-Hour energized first heavy fattening sluggish',
#  'perfect sure excellent fresh',
#  'wish black Unbelievable Good full faulty horrible',
#  'strong different it. plastic other < favorite fantastic gallon-sized',
#  'gluten-free versatile fish Good good',
#  'healthy mixed healthy good such great healthy',
#  'great healthy wk old sure',
#  'hard affordable only',
#  'many recent disappointing crystal regular large mixed recent many similar crystal new-crop 6-10 Julian recent initial Bottom current much',
#  'worsens no-burn',
#  'muscavado great regular white',
#  'retail Easy individual',
#  'much real other local < sweet few brown few pure white liable',
#  'white suppose resealable',
#  'delicious light brown delicious big difficult great perfect',
#  'raw little normal good',
#  'good white white terrible well-packaged only happy',
#  'great content next',
#  'much',
#  'much overly sweet regular few good good easy everyday',
#  'Ca bad other natural natural sure unnatural',
#  'efficient excellent',
#  'one-star main whole brown second rice gluten free excellent gluten free delicious',
#  'addicted good',
#  'many healthy good good tasty nice gluten-free borderline diabetic',
#  'local yummy regular big only entire big',
#  'special whole',
#  'brown good deceptive similar',
#  'daily weird spagehetti good chili indian spicey canned local inflated',
#  'amazon local local',
#  'actual good i own local eight+ half < [ * local',
#  'wrong other edible spicy-hot comfortable mixed diced hot southwestern good',
#  'fantastic available second concentrated sweet big red sucralose sugar only horrible subtle black 8-12 Overall real organic moderate big',
#  'early super extra jittery skeptical jittery fig ok < organic good good',
#  'hard Good',
#  'sure same natural',
#  'organic assorted ingredients. iced',
#  'natural favorite < gastric no-no allergic other out. like bad all. natural',
#  'natural sure little expensive sensitive natural little weird whole same whole nice sinthetic good sure',
#  'drinkable',
#  'late unacceptable nice local extra suspicious little green unnatural br shot anything.',
#  'terrible first glad other other aspartame-laced',
#  '5-hour red other favorite reassuring natural other past',
#  'artificial other great decent nice smooth',
#  'local organic delicious bitter sensitive many actual artificial slow several medical intense expensive bulk thrilled',
#  'other only good other fresh',
#  'alert high good',
#  'good effective weight high unnatural',
#  'steady slight',
#  'excellent continuous ~6-hour recent heinous fake other non-organic',
#  'first other 5-hr Rain ok nose medicinal tic rid weird tea-flavored other big',
#  'last first other main',
#  'regular good',
#  'easy great good hot cold other other mixed oilive added big',
#  'tri-color couscous good full minced red olive wonderful',
#  'israeli couscous upsacale good ole good..add few great salad.so good hooked easy',
#  'couscous-brought mushy',
#  'other',
#  'whole bean much first big flavored flavored',
#  'Many flavored',
#  'available local local good bad expensive local rich flavored',
#  'hot tasty little hot',
#  'hot mild much hot hot hot br hot earthy much hot < good',
#  'great Swiss br',
#  'Asian usual',
#  'delicious few sweet sugar-free traditional marzipan-aholic',
#  '',
#  'cute user',
#  'typical major',
#  'positive',
#  'big',
#  'single much easy other',
#  'Other happy',
#  'obvious individual many many multiple negative due broken sloppy thick good inner sloppy drippy first. mini negative other reasonable',
#  'nice good only free fat',
#  'great',
#  'timely awful',
#  'new colorful detailed bright only fantastic',
#  'non delicious delicious extra right',
#  'stale 50th stale',
#  'excellent old i',
#  'perfect',
#  'advertised few awesome entire',
#  'sesame',
#  'few busy great big new',
#  'different different sticky vegetable much',
#  'GREAT difficult like',
#  'impossible',
#  'other new great though-impossible clean',
#  'little fresh other tasty only impossible difficult much much next removable replaceable',
#  'fresh okay interested little',
#  'amazing few little',
#  'good big great tasting',
#  'delicious excellent espresso perfect bitter',
#  'advertised fresh',
#  'espresso wonderful dark rich delightful',
#  'good good',
#  'great Whole Canadian own competitive',
#  'sweet Belgian pretzel',
#  'small great',
#  '',
#  'strawberry common good sugary good give < interested right liquid extract',
#  'dependable high whole',
#  'favorite darned little',
#  'strict clean strong correct organic zen appropriate caffeinated',
#  'other sure average real',
#  'bitter bitter',
#  'Latin American South American distinct caramelish hooked French perfect french fans.',
#  'br bad',
#  'favorite dark wonderful filling hard thankful',
#  'dark nut',
#  'great',
#  'happy hard local reasonable ready',
#  'single',
#  'Green good > smooth > good',
#  'excited open sample different underwhelming Green last glad < nice flavorful thick other flavored go-to standard new exciting pleasing able Green disappointing open few 24-Count go-to',
#  'Green favorite favorite Green smooth strong weak',
#  'Green nice strong',
#  'Green everyday perfect excellent',
#  'Fantastic large hearty nice large full glad',
#  'several regular sorry great green',
#  'good whole amazing',
#  'great classic wonderful refreshed great disappointed hard sure spiced classic first',
#  'ridiculous pricey great hard',
#  'classic clean fresh complex good crazy',
#  'bad expensive regular sweet Horrible',
#  'terrible classic sweet spiced bad',
#  'twenty extra',
#  'pleased large re-hydrated good small likely due large small small/minced-size/dust-like useful like < quite dried fresh big wonderful dried wonderful earthy mushroom-infused first',
#  '',
#  'nice big vast whole small many absolutely excellent decent clear lb convenient ready it.',
#  'several fine vegan other perfect great',
#  'fair online 1-3oz sceptical cheap good bad / pretty fast fresh whole broken clear first good second fresh air-tight fresh only negative',
#  'fresh tasty dirty',
#  'fresh last long',
#  '',
#  'free much sure',
#  'great seasoned',
#  'ham',
#  'delicious fluffy. small regular',
#  'free great good wonderful',
#  'favorite great light fluffy super easy pure organic',
#  'great recipe great able fresh available',
#  'GREAT thin warm brown 13-Ounce awesome extra',
#  'glad allergy. fine family- many',
#  'foolish',
#  'open full',
#  'awful good ice bad',
#  'sure thin characteristic good bitter pinot low other favorable',
#  'good light good potato',
#  'wonderful sweet chamomile subtle hard sweet chamomile sweet',
#  'organic natural other other pale plain apparent last other',
#  'simple good extra hard usual use first great great simple',
#  'grande Delicious ultimate main',
#  'same tasty good perfect',
#  'good Indian creamy tasty only enough good good delicious',
#  'little i',
#  'local available',
#  'tasteless flavorful',
#  'Side slow',
#  'good little great easy',
#  'much English wonderful available affordable Last British quick efficient last Good',
#  'miserable flat anemic whole organic',
#  'fantastic only',
#  'green fresh local',
#  'much chocolate soft much rich real moist great',
#  'good unreliable',
#  'resemble regular dry hard',
#  'great loaded flavorful sweet great-tasting great',
#  'bags hefty nearby pleased jalapeno slow-building whole embarrassed few well-packed fresh pretty impressive local expensive',
#  'important oz good full',
#  'full hard single wide plump good',
#  'many slight delicious alone. < anonymous',
#  'excellent favorite next',
#  'few non-baked sweet',
#  'much large unique other only bad nasty sour great 2-Ounce good liquid actual fine many perfect',
#  'side-by-side real regular',
#  'other many big < much potato',
#  'thick perfect trust large good',
#  'usual jalapeno same great small',
#  'right much subtle great',
#  'vinegar vinegar close flavorful other good',
#  'local new',
#  'favorite gluten-free dairy-free Many other vinegar nice intense good',
#  'garlic sure other sure thick heavy-duty regular thick nice Sure small top simple easy',
#  'okay bad old fancy cheese < long-lingering bad crunchy greasy napkin',
#  'humble pepper new pure real great addictive low fat low fat excellent',
#  'vinegar favorite tasty healthy same great',
#  'thick natural subjective few gross much true rid',
#  'tangy many crisp',
#  'vinegary typical',
#  'subtle definite < nice burnt only negative uneven nice big all. fantastic great',
#  'many salty greasy good other short mouth delicious',
#  'favorite sure personal real',
#  'right consistent even 2-oz right',
#  'favorite other much local steady works large good own single perfect crunchy fresh < only yummy easy',
#  'tangy super great OK little vinegary hard-boiled feet. cold',
#  'delicious fresh',
#  'perfect',
#  'perfect enough little extra substantial wonderful great hot casual',
#  'local simply-flavored asian-inspired awful awesome different real sour well-made well-balanced',
#  'professional Rich impossible entire true',
#  'hands-down great strong favorite',
#  'hard',
#  'little weird potato great right right little ok oz oz little sure',
#  'past several big good small overwhelming good',
#  'good bad moral strong large new',
#  'terrible simple delicious light lip occasional entire',
#  'little sandwich sure first <',
#  'good addictive crunchy right perfect salty small',
#  'beat other tangy only same',
#  'addicted first perfect vegetable tangy raw Oregonian proud delectable outside gourmet unmistakable light rich amazing major artificial organic > > br wonderful semi-sweet white moderate strong garlic German-style',
#  'terrific Other much great baked grilled great beer. Oregonian proud delectable outside gourmet unmistakable light rich amazing major artificial organic other > > br wonderful semi-sweet white moderate strong garlic German-style',
#  'long obsolete middle impossible blue',
#  'favorite crunchy similar other extreme several other',
#  'good cheese wish good free similar crispy.',
#  'good healthy',
#  'delicious big',
#  'delicious brown little disappointed many brown good green thicker fresh',
#  'fresh tasty',
#  'greasy old',
#  'great special hard favorite',
#  'fantastic spice',
#  'own Good',
#  'many quick packed great natural brown hardy',
#  'cheese-favored salty little greasy great',
#  'yummy substantial regular',
#  'tasty right',
#  'disappointed sized <',
#  'good',
#  'different greasy usual pretty sturdy bad',
#  'light',
#  'disappointing little sour',
#  'good subtle great > /a obvious garlic other good',
#  'good sudden happy garlic other great',
#  'other delightful cooked dark few golden',
#  'guilty happy',
#  'mine unchanged kettle Kettle thick greasy amazing hot hot',
#  '',
#  'easy perfect other fibrous good normal. < great',
#  'eat amazing thin delicious i',
#  'hot wrong < hot-with-a-hint-of-sweetness prevalent',
#  'perfect good kettle-cooked over-browned thick thin great tremendous tangy great big artificial fat fabulous',
#  'potato spicy hard < many br',
#  'many dynamite healthy lil',
#  '',
#  'great vinegary',
#  'Perfect favorite',
#  'perfect added only',
#  'ruffly thickly thick great great favorite much',
#  'unsalted many',
#  'great fish vinegar spectacular deli own palatable intelligent heavy bitter sweet wont first only whole',
#  'cheese big stale favorite',
#  'entire favorite them. powdered powdered sour awful sour sour unappealing particular chalky hard exists. wonderful kettle',
#  'favorite crinkle favorite',
#  'excellent tasty good',
#  'entire great good other',
#  'first sure black',
#  'plain free fast',
#  '< only multiple saying. wrong classic same small good adult. typical fried bad about. Delicious',
#  'large great reasonable',
#  'greasy rich major great clear',
#  'crunchy kettle-cooked',
#  'decent good awesome',
#  'salt-free greasy',
#  'much perfect perfect',
#  'darn cheddary',
#  'tasty first Other other crunchy salt-and-vinegar original palate-pleasing tongue-puckering poetic < such hand-cooked small favorite iced delicious hot perfect delicious last good appetite hard easy much',
#  'trans-fats low-salt available',
#  'potato < potatoe < great <',
#  'strange absolute favorite regular < much dark browned snob',
#  'Real authentic',
#  'crunchy regular old soft bad clear super other soft whimpy gourmet',
#  'only local much uniform whitish lovely extra disappointed e-mailed other different else cooked weird color-but great nut great next same rare same same next good bad pretty sure private same high increased valuable nice unsuspecting exploited same',
#  'last full Last GOOD wrong full real crisp fresh delicious',
#  'great nice fresh other',
#  'optimum required. whole Total ok burnt bad burnt there. free',
#  'tangy',
#  'overcooked brown greasy',
#  'first darn',
#  'impressed flat unopened type same multiple much full',
#  'associated',
#  'much real',
#  'numerous gross',
#  'worried other other good potato deep other < potato-chip several potato-chip favourite different first different flavour little br happy delicious same same and/or stronger-than-adult strong jalapeno strong < right cayenne natural complete < < br natural true < ptato .which good much vegetable great much much large < good good much bad natural only good ..M < large small potato several normal s-l-o-w-l-y big many little sensible ten last br scrumptious jalapino good spicy own top <',
#  'okay greasy strange bad able',
#  'local salty few leave many stale Unedible special close due stale unedible same',
#  'GOOD last long. little hard sure',
#  'good flavorful other big good',
#  'other total awful great awful',
#  'nasty',
#  'salt vinegar actual actual i only full brown bad overcooked burnt rare extreme br high sour normal',
#  'natural over-fried brown over-fried other same bad same sure',
#  'good wish',
#  '',
#  '',
#  'low low many many other unappetizing',
#  'mild many ahold bad great kettle',
#  'buffet terrific due these. similar bbq exact opposite. little flavorful unique',
#  'greasy fat free greasy',
#  'sour',
#  'tasty dark/burnt broken light',
#  'sour strong sour sour strong',
#  '',
#  'first able on-line such great wonderful quick simple great',
#  'unhappy few flavored free whole real yeast < horrible full baked sour rancid. kettle new cheap premium premium',
#  'great first few first black sticky Other same sealed hard',
#  'ridiculous open outside outside intact disgusted sick < little high now. above',
#  'unto such delicious veritable strict other',
#  'hot absolute favorite sour',
#  'great happy great spicy nice careful worth',
#  'Terrible embarrassed gross insulated bubble unhappy stale crusty',
#  'nervous recent great first good expensive local',
#  'good fried waaaay burnt cheese old new other other',
#  'glad able crunchy',
#  'awesome other flavored sure individual pretty',
#  'careful fantastic dark golden crunchy it. burnt quick immediate beautiful natural light deep deep rich artisanal / true and/or free fatty extra independent third free natural used. natural unsalted unsalted',
#  'CostPlus big dijon-flavored few northwestern available available < big delicious last great hot perfect outdoor hidden',
#  'other same blue',
#  'addicted first perfect vegetable tangy raw Oregonian proud delectable outside gourmet unmistakable light rich amazing major artificial organic > > br wonderful semi-sweet white moderate strong garlic German-style',
#  'thick great',
#  'hard regular fine',
#  'new big sure good pretty good-no potato flavorful honey-dijon good flavorful hot Excellent < good',
#  'real good wrong',
#  'whole only',
#  'potato',
#  'br great stale. great over-eating',
#  'oversalted addictive',
#  'crisp low',
#  'fabulous local crisp tasty',
#  'super first many good unique sweet different little',
#  'healthy unsalted great only hard/crunchy same',
#  'favorite wrong rich single entire available entire',
#  'favorite high greasy right',
#  'single rough outstanding < sure again. particular numerous other',
#  'jalapeno',
#  'addicted. < many other dietary individual nice good them. hot many slow noticeable decent happy few local',
#  'crushed numerous few fresh hard ok. great perfect great tasting good quick',
#  'good bad potato fresh crunchy transparent spicy',
#  'daily whole returnable close',
#  'second much first single delicious artificial real great',
#  'simple < old < delicious',
#  'good hard whole',
#  'full awesome',
#  'fantastic whole local amazing many delicious personal recommend nothin',
#  'other unsalted terrible much unsalted natural crunchy only bad',
#  'thick creative favorite great snack extra 2-oz perfect',
#  'Oregonian Oregon-made unmistakable light rich amazing major artificial organic wonderful semi-sweet white moderate strong garlic German-style < > > br terrific Other much great baked grilled great beer. perfect vegetable tangy raw summary great',
#  'addicted first perfect vegetable tangy raw Oregonian proud delectable outside gourmet unmistakable light rich amazing major artificial organic > > br wonderful semi-sweet white moderate strong garlic German-style',
#  'other great overwhelming great',
#  'first doesnt addictive ultimate',
#  'good good',
#  'delicious potato only kettle fried small strong satisfying Delicious',
#  'difficult such scissors. crispy healthy too. high-quality',
#  'classic unique right wonderful all-natural Green environmental roof-top solar additional renewable present neighboring acre recent <',
#  'blue subtle cheese',
#  'delicious low kiss beleive total',
#  'salty regular for. artificial home-made excellent',
#  'small local strong mild whole other',
#  'favorite flavorful happy entire empty < online else great',
#  'new new strong much fabulous',
#  'good whole good glad',
#  '',
#  'fresh current',
#  'first cheese delicious yummy',
#  'important good non-existent. original new ingredient < garlic jalapeno citric natural lime new rid natural. great',
#  'Fresh fresh again. expired black hole bad',
#  'good delicious gourmet first natural tangy crunchy other',
#  'good mealy old expensive good fresh last weird sour bad',
#  'vinegar white first x many high mellow sour sour strong many thick expensive high',
#  'salt pleased these. confirmed salt-aholic green satisfying robust nice able much',
#  'zippy tart unpleasant natural little',
#  'favorite fancy super full',
#  'tasty low regular greasy salty much greasy',
#  'Fantastic potato great artifical high great high',
#  'large strong tasty actual authentic non-manufactured',
#  'happy snack',
#  'good much good general nutritional sharp top rodent hungry able *wow* corrugated ripple/ridged important. good other',
#  "rediculous wrong jalapeno similarly-colored jalapeno next jalapeno other excellent 'affection-ados'.",
#  'available sure tough right noticeable',
#  'allergic plus many minus worth hard wrong light due harsh',
#  'awesome much last',
#  '',
#  'great good beat good',
#  'delicious < top bergamot. little much. perfect 2-3 ready. expensive',
#  'pricey smooth',
#  'well. beautiful right. first much long < br competitive',
#  'fragrant < Nice air-tight Organic / 3.5-Ounce',
#  'excellent loose fresh inner own attached dry fresh',
#  'delicious sweet enough Quick satisfied',
#  'Excellent lo-fat lo- German favorite',
#  'male Maltese Puppy desperate little guy high high',
#  'great early renal',
#  'fry little hot tasty',
#  'Last pleased weird smokey little heavy odd wonderful rich fine strong such treat. such happy new different own potent much light',
#  'commercial Bavarian wonderful store-bought < excellent',
#  'difficult ideal flat. unique great unique available widely. next',
#  'old fashioned lovely green gnome different typical strong ginger good dry sugar same high cost-cutting mega down Many great other upset regional many first second famous',
#  'good maple brown agave baked 2-pack. Other small little long dried much dry sure dry < other able hard br caramel light good',
#  'Good tasty. weight.',
#  'First great stable',
#  'true great',
#  '',
#  'natural added low glycemic delicious many economical',
#  'little expensive same little sweet right sticky fine other',
#  'other low glycemic bitter',
#  'happy great',
#  'great',
#  '17-Day 6-7 fair primary low glycemic mellow ] kombucha sure good raw own actual < primary little salad nice local same',
#  'glad much herbal sweet much first hooked clean fresh long',
#  'natural many last long good',
#  'several good good',
#  'great low great economical mine',
#  'little Good frozen',
#  'awesome many Honey-like glycemic great',
#  'excellent',
#  'low glycemic agave low low wholesale br equal whole flour white other delicious good',
#  'disappointed many',
#  'awesome fabulous 1st flavored',
#  'conventional spicy enjoyable',
#  'allergic tortilla much miss right flovorful',
#  'potato difficult organic pure artificial true present',
#  'great',
#  'plain sweet same only tad much great',
#  'hot much great good good tasty crunchy hard hard',
#  'right hot sweet hard',
#  'wonderful extra',
#  'perfect brittle thin other only minimal',
#  'little',
#  'Sweet spicy- good perfect crushed Fantastic',
#  'nice tasty',
#  'organic burning sweetish strongly-flavored delicious barbecue nice sweet-Mexi-fied organic. bad delicious. whole organic fried flavorful delicious small low-fat soup. <',
#  'first good',
#  'good black satisfying guilty satisfied themselves..no',
#  'actual other awesome',
#  'excited favorite good favorite',
#  'crisp tasty',
#  'tasty sure different right crunchy flavorful much. red other nachos',
#  'unique incredible',
#  'only tasty healthy fat good perfect',
#  'local great',
#  'great stanky first next careful',
#  'first terrific Good ok good',
#  'delicious solid wrong regular mid-bag low 8-9oz',
#  'local fresh delicious healthy',
#  'tasty few Good good artificial',
#  'us. br good. healthy <',
#  'soooo good overwhelming',
#  'respectable free',
#  'different fantastic',
#  'like black tasty good',
#  'nice sweet smoky little',
#  'tasty great',
#  'crisp',
#  'little hot empty empty <',
#  'unable local great favorite same ta hooked',
#  'anodyne second last long',
#  'Mexican picky light crispy fantastic flavorful embarrassing amazing fresh',
#  '/a available first open',
#  'other great available accessable. <',
#  'huge unconventional wonderful strong',
#  'autolyzed different same safe',
#  'flavorful bad',
#  'several whole little regular great organic difficult empty glad',
#  'great minimal',
#  'high low unable light flavorful good',
#  'amazing light crisp great nice natural low regular',
#  'fantastic whole whole complete great only small',
#  'potatoe hot overwhelming',
#  'good',
#  "short tasty favorite. br popular different whole plain bothersome. large premium 'organic deceptive",
#  'Wonderful hard huge sturdy heavy great',
#  '',
#  'surprised Taiwan-shaped cute < pineapple local Asian lovely good',
#  'artificial real whole traditional interested next',
#  'Big sure other',
#  'big red amazing next',
#  'edible real enjoyable',
#  'cinnamon wonderful natural moist great little sweet bad delicious',
#  'few free different',
#  'concerned like dried white indescribable gelatinous white < gelatinous white long own easy little powdered tiny tiny fluffy whole < positive frosting next',
#  'grayish sticky mad live learn',
#  'Ready needed picky horrible regular light fluffy gooey thick off-putting',
#  'such other sticky akin edible bad own good hard',
#  'glad bad bad Horrible',
#  'local < creamy white bad gluey/tacky right great sweet only right',
#  'generous different Horrible bad good pre-made long gooey ugly',
#  'good GREAT',
#  'different excellent approx good',
#  'good dirty wild various good large large canned fair liquid due high fat helpful mild -like spam Due',
#  '< < < < < < < < Phosphorous *Percent diet Gluten-Free excellent thick good much personal many tasty sweet thick tiny ingredient confusing fresh high high high many beneficial noteworthy',
#  'strong tart br br distinctive milky exotic unique nutritious real',
#  'excellent organic recycled organic organic whole organic organic organic pasteurized non-animal organic flavored whole cheese wonderful firm excellent artificial synthetic persistent simple wonderful cheese sufficient wonderful rich cheese own organic cheese flat sufficient organic',
#  '',
#  "super spankin'.this bomb",
#  'disappointed weak watery definite',
#  'good regular super-wonderful-better other good Asian main unique Japanese usukuchi raw light regular good commercial available flat complex interesting salty full complex initial full direct many standard Japanese other soy used. good different favorite unique Asian different standard',
#  'several many past many real handmade American Japanese/Chinese national',
#  'light subtle right extra great little affordable unique traditional common boring',
#  'good',
#  'impressed good excessive little extra American good',
#  'able big',
#  'delicious Such deep',
#  'interesting < several dishes.',
#  'soy soy sure last',
#  "pleased sure able classic good diabetic real tasty real many near last 'will",
#  'loose unopened free',
#  'bold great complex fantastic',
#  'many favorite normal rich stong current',
#  'available available excellent full bitter favorite',
#  'available regular/unflavored nice overpowering pleasant mild gluten-free available available Dead happy final',
#  'good special nice mellow favorite daily first Canadian long < legal happy careful local such ordered. good usual small European extra large aware',
#  'available fantastic favorite',
#  'favorite light creamy bad two-hundred many',
#  'good like',
#  'unique usual wrong nice. few alpine delicious eager perfect work. famous purple eastern European available other nearby weak international eclectic basic',
#  'whole br good',
#  'expensive small expenive',
#  'real',
#  'bad few other bad',
#  '',
#  'local gourmet affordable Wrong gel few much disappointed',
#  'ferret nice high regular reasonable local',
#  'precise polite < tangy perfect sandwich heavy deli whole sourdough sure delicious',
#  'great bee-themed',
#  'edible such',
#  'happy quick',
#  'easy stuck unwind. hard br yellow small white green small white < clear small br small < little',
#  'fanatic excited yellow edible yellow outside worked great fun worthless',
#  'easy enough yellow old',
#  'gingerbread odd unable glue non returnable nice second same come overnight bubble wrapped good cute first second bad',
#  'speediest happy excited',
#  'tasty < much br them.',
#  'bigger. enough own',
#  'whole great good cute happy',
#  'terrible only alive. like like moldy whole',
#  'possible huge excited new hot other',
#  '',
#  'added sweet wonderful healthy dinner. personal different different',
#  'humble many actual rare long other many',
#  'good many tasty fast',
#  'wonderful',
#  'liquid refined br',
#  'delicious local',
#  'great right',
#  'first quick great',
#  'ummmm',
#  'Low nice much hungry few',
#  'fine real cheap nutritional cookie cheap daily OK',
#  'pretty minute high plastic nice',
#  'lightning happy',
#  'sized adorable',
#  'small able past jello solid edible alternative small',
#  'big high good',
#  'able',
#  'Delicious own local happy on-line. < unaware impressed little cordial other chocolate Excellent',
#  '< delicious',
#  'long-lasting pleasant other bad next',
#  'disappointing artificial good stringy quickly.',
#  'other hard akin extraordinary short',
#  'fresh',
#  'other yahoo taste- br delicious smooth squeaky. wonderful dietetic odorless <',
#  '',
#  'old numerous good good only',
#  'several only tooth-cleaning fancy',
#  'specific difficult expensive per great',
#  'happy fresh long Great',
#  'many different specific significant active well. now.',
#  'old puppy old sensitive black hot great great. specific next bi-monthly Sept huge due local large',
#  'great low great',
#  'nice great',
#  'old good few',
#  'much many weekly high much',
#  'organic minute oatmeal soggy Instant',
#  'delicious timely amazing',
#  'bitter whole',
#  'distinct new',
#  'different differently. silky smooth easy high',
#  'first stale giant Chinese straight. Other odd strong smoky enough own expensive loose large fantastic well-sealed true loose whole',
#  'other tea-drinking old wonderful',
#  '/a iced large',
#  'harsh ok able',
#  'last delicious good black several other',
#  'favorite happy economical great large habitual daily regular nice aromatic flavorful flowery subtle nice',
#  'fine much last excellent insipid impossible decent little natural floral',
#  'write excellent other added flavorful great fine loose first premium',
#  'other pleased other happy',
#  'fine creamy fine little',
#  'all-time rave easy chewy little spectacular OK',
#  'other tiny enjoyable Wonderful future other walnut sure',
#  'whole',
#  'good rich caramelized',
#  'old pleased',
#  'great acid half alkaline great pH',
#  'pleased sure',
#  'free bad hard regular great general natural perfect. little br amazon.com-land excellent',
#  'high rich full fast. only negative addressed heavy significant inner heavy zip-lock twist practical it. small expensive hard single senior staple Long big',
#  'happy other plastic quality good high',
#  'fresh good anymore. large favorite',
#  'Good single food- excellent',
#  'funny funny OK own',
#  'pocky couldnt good only sad hot much great',
#  "many past pleased 'hit surprised sure",
#  'good good',
#  'sure subjective normal eating. nitty little slit folded hassle ta Japanese nice right good sheanut nice sensitive great great few hot',
#  'good',
#  'heatproof cold free delicious',
#  'many Japanese mind easy amazon.com/gp/help/seller/at-a-glance.html local good different front japanese pocky~ish giant fine cooler melted front thick bitter similar original Japanese dark pocky terrible small opened pocky original true Japanese terrible possible',
#  'great',
#  'old',
#  'plain anime manga slim waffle tiny nice non-dark popular fast nice. same fat non-healthful habitual prone whole huge reasonable multiple nibble cool good oh similar old < young stick-looking cute Japanese skinny little stick crazy hot local deep local Japanese Japanese',
#  'good impressed easy dead dessert liquid special pocky perfect',
#  'Many messy',
#  'good minimal few broken',
#  'great them. next enough <',
#  'Asian',
#  'individual',
#  'deceptive normal normal empty so-so dry inferior one. same deceptive normal sized plastic quarter. hard new many hard popped people. <',
#  'first free tasty strawberry soft clean last wonderful subscribe',
#  'few dietary gross miserable much allergen free',
#  'extensive safe last few several previous total past new',
#  'multiple good nice',
#  'sweet allergy free great REAL',
#  'disappionted generic new Next old new good-tasting wrong summary expensive unpalatable',
#  'two-bite deceptive expensive old different tasty concerned',
#  "great negative many 'on-the-go several great occasional healthy dense filling-not 'soft same",
#  'new severe local excited it. good dense light whole big < many other real non grateful several quick stranded',
#  'severe good great',
#  'celiac',
#  'great gluten free sorry favorite',
#  'good favorite small gluten free other normal good tiny GREAT small',
#  'OK celiac raspberry other < other',
#  'Great Great delicious little hungry old little hungry good',
#  'gluten-intolerant former traditional pleasant',
#  'typical first',
#  'good healthy good',
#  'flavorful nutritional healthy bad edible neanderthal-era gluten free bad local different br expensive else.',
#  'original own delicious good own',
#  'light full pleased resealable much other intact wont',
#  'American popular American happy',
#  'exotic white gum-ball open central amaranth decorative glass br white mild rich wonderful jasmine balanced tasty small able yummy white plentiful high bitter periods. high hot fair main intact central this. good short',
#  'first little hot good long white',
#  'wonderful pleasant other',
#  'horrible few Indian',
#  'old glad green sweet sweet glad brown complete prime brown local glad busy great br excellent unbelievable different arrive organic organic organic organic organic iron. informed daily',
#  'twin 10-month old first straight first apricot good brown < puree much organic organic separated organic organic real nice sweet nice iron. daily',
#  'twin 10-month such interesting vegetarian complete looks excellent green green. organic organic organic green organic organic organic organic daily',
#  'runny little potato',
#  'next non-sweetened non-dried turkey good 10-month old twin sweet great whole acceptable organic organic separated organic organic whole iron. pleased many daily',
#  'little organic tasty old',
#  'favorite first lentils many vegetarian',
#  'clear other little sad organic baby',
#  'organic great free busy other other added digestive poop sippy main sweet',
#  'favorite great',
#  'bubble single great',
#  'thin much careful',
#  'great smooth',
#  'organic pretty gross much other decent important vegetarian',
#  'Soft texture little',
#  'runny',
#  'good bad runny',
#  'big sweet savory strong plain sweet sharp good first good picky pretty safe particular other runny fine extra workable',
#  'only great',
#  'lentil brown amazon',
#  'twin favorite Great',
#  'new little soft first ok fine angry disappointing',
#  'entire',
#  'early advanced overdue first other least favorite favorite',
#  'first sure right 6-9 yucky old other organic',
#  'turkey favorite good',
#  'edible spongy brown yellowish good disappointing',
#  'favorite sweet runny other little',
#  'happy',
#  'absolute much personal particular runny great',
#  '7-1/2 old favorite jarred protein average ready yet. fair amazing equivalent particular hard regular much good',
#  'good',
#  'ate solid picky many different various only whole green vegetable < old healthy current tofu brown fabulous great good',
#  'Little watery objective different',
#  'good cat open bad poor bubble air-cushioned',
#  'great great open go',
#  'old old local other other glad little other cooked small new',
#  'favorite able',
#  'natural Good other',
#  'baby good',
#  'favorite healthy organic',
#  'fair horrible young',
#  'easy enough nasty poor asparagus',
#  'old favorite easy thick thin',
#  'favorite only other unfinished unique zucchini. little thin stretchy',
#  'earths little original runny',
#  'many Great',
#  'savory sweet fine jarred common hard crazy different trash lazy',
#  'small old please careful it. favorite first',
#  'good pretty smooth energetic',
#  'true',
#  'fresh sweet Happy healthy',
#  'perfect fresh tasty tasty delicious thank',
#  'fresh dark dark Next',
#  'facorite fresh fragile great great',
#  'plentiful few delightful good expensive average much good',
#  'on-line few excellent right',
#  'present sassafras long hard great',
#  'great 4-pack',
#  'many i',
#  'local teabag several dissapointed flat black mild distinctive red sassafras real real Bottom',
#  'good br',
#  'same elementary particular',
#  'natural awful yucky',
#  'good good unsalted hard unsalted salted',
#  'white own hot fresh brown hot',
#  'highway excellent good',
#  'easy add light full heaping green red full',
#  'mixed medicinal strong horrible horrible expensive',
#  'gravy excellent',
#  'southern gravy DE-LICIOUS + phenomenal small super easy',
#  'white gravy',
#  'easy great',
#  'great able good unhealthy fair good happy',
#  'fanatic instant similar instant expensive fresh acceptable first local little high local able single supposed free great x = single expensive',
#  'good fresh fresh instant hot hot tea instant hot tiny early',
#  'Regular old iced',
#  'easy decent good',
#  'primary expensive other money. many many like instant nice special sure good good easy tasty in-room',
#  'in-house high separate fresh hot tasty',
#  'great instant easy',
#  'easy delicious great easy Good',
#  'tea glad sweet minty wonderful nice reddish wonderful japanese green',
#  'normal red muddy worth',
#  'other green competitive tried- fresh consistent great same',
#  'concerned -of own',
#  'great free other superior good Celiac intolerant salt',
#  'new pleased natural',
#  'hot perfect tasty other hot',
#  'hot local good extra Happy',
#  'favorite hot extra favorite great',
#  'local hot awesome good hot',
#  'pleased favorite favorite tangy wrong',
#  'favorite hot other flavored flavorful hot',
#  'extra thick last heavy added',
#  'good theis homegrown',
#  'flavorful nice yummy meal. many different hard hard',
#  'different cool free i first dont hot',
#  'good asian good strong other pineapple',
#  'hot other low oz fish hot',
#  'large hot wing-sauce convenient overall hot tasty <',
#  ...]
